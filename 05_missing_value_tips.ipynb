# %%
import numpy as np
import pandas as pd
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_copy = tips.copy()

# %%
tips_copy.loc[1:5, 'smoker'] = 'Yes'
tips_copy.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male    Yes  Sun  Dinner     3
# 2       21.01  3.50    Male    Yes  Sun  Dinner     3
# 3       23.68  3.31    Male    Yes  Sun  Dinner     2
# 4       24.59  3.61  Female    Yes  Sun  Dinner     4

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips.notnull().sum()
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
## nan 값이 없어서 fillna 사용 실패!

# %%
df = sns.load_dataset('titanic')

# %%
df1 = df.copy()
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df1['deck'] = df1['deck'].fillna('A')

# %%
df1.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True    A  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False    A  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True    A   Queenstown    no   True

# %%
df1['deck'].fillna('C')
# Out:
# 0      A
# 1      C
# 2      A
# 3      C
# 4      A
#       ..
# 886    A
# 887    B
# 888    A
# 889    C
# 890    A
# Name: deck, Length: 891, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
df1 = df.copy()
df1['deck'] = df1['deck'].cat.add_categories('X')
df1['deck'].fillna('X')
# Out:
# 0      X
# 1      C
# 2      X
# 3      C
# 4      X
#       ..
# 886    X
# 887    B
# 888    X
# 889    C
# 890    X
# Name: deck, Length: 891, dtype: category
# Categories (8, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'X']

# %%
df1.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1.drop(columns=['pclass'])
# Out:
#      survived     sex   age  sibsp  parch     fare embarked   class    who  \
# 0           0    male  22.0      1      0   7.2500        S   Third    man
# 1           1  female  38.0      1      0  71.2833        C   First  woman
# 2           1  female  26.0      0      0   7.9250        S   Third  woman
# 3           1  female  35.0      1      0  53.1000        S   First  woman
# 4           0    male  35.0      0      0   8.0500        S   Third    man
# ..        ...     ...   ...    ...    ...      ...      ...     ...    ...
# 886         0    male  27.0      0      0  13.0000        S  Second    man
# 887         1  female  19.0      0      0  30.0000        S   First  woman
# 888         0  female   NaN      1      2  23.4500        S   Third  woman
# 889         1    male  26.0      0      0  30.0000        C   First    man
# 890         0    male  32.0      0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
df1.drop(columns=['survived']).dropna()
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked  class    who  \
# 1         1  female  38.0      1      0  71.2833        C  First  woman
# 3         1  female  35.0      1      0  53.1000        S  First  woman
# 6         1    male  54.0      0      0  51.8625        S  First    man
# 10        3  female   4.0      1      1  16.7000        S  Third  child
# 11        1  female  58.0      0      0  26.5500        S  First  woman
# ..      ...     ...   ...    ...    ...      ...      ...    ...    ...
# 871       1  female  47.0      1      1  52.5542        S  First  woman
# 872       1    male  33.0      0      0   5.0000        S  First    man
# 879       1  female  56.0      0      1  83.1583        C  First  woman
# 887       1  female  19.0      0      0  30.0000        S  First  woman
# 889       1    male  26.0      0      0  30.0000        C  First    man
#
#      adult_male deck  embark_town alive  alone
# 1         False    C    Cherbourg   yes  False
# ...
